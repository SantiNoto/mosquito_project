# %%
import pandas as pd
# Out:
# C:\Users\santiago.guillen\.conda\envs\MLBasic\lib\site-packages\numpy\_distributor_init.py:32: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\santiago.guillen\.conda\envs\MLBasic\lib\site-packages\numpy\.libs\libopenblas.WCDJNK7YVMPZQ2ME2ZZHJJRJ3JIKNDB7.gfortran-win_amd64.dll
# C:\Users\santiago.guillen\.conda\envs\MLBasic\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   stacklevel=1)

# %%
df = pd.read_csv('../../data/Korle-Bu_coluzzii_PM_randomised_Fst.csv',delimiter='\t')

# %%
df
# Out:
#      window.chrom  window.pos  phenotype.moving.Fst  r0001.moving.Fst  \
# 0              2L      334240                -0.001             0.001
# 1              2L      527970                -0.003             0.005
# 2              2L      765225                -0.001            -0.001
# 3              2L     1079162                 0.001            -0.003
# 4              2L     1458737                 0.020             0.004
# ...           ...         ...                   ...               ...
# 8534            X    21058510                -0.002            -0.002
# 8535            X    21608792                -0.004            -0.003
# 8536            X    22183773                -0.003            -0.005
# 8537            X    22989453                 0.002            -0.003
# 8538            X    23416987                 0.004            -0.004
#
#       r0002.moving.Fst  r0003.moving.Fst  r0004.moving.Fst  r0005.moving.Fst  \
# 0               -0.001            -0.002             0.000            -0.006
# 1               -0.002            -0.001             0.001            -0.007
# 2               -0.001             0.000            -0.001            -0.006
# 3               -0.003            -0.003            -0.003            -0.007
# 4                0.005            -0.005            -0.005            -0.005
# ...                ...               ...               ...               ...
# 8534            -0.003            -0.003             0.001            -0.003
# 8535            -0.002            -0.003            -0.001            -0.005
# 8536            -0.004            -0.003            -0.002            -0.004
# 8537            -0.004            -0.002            -0.005            -0.004
# 8538            -0.004             0.000            -0.003            -0.003
#
#       r0006.moving.Fst  r0007.moving.Fst  ...  r0991.moving.Fst  \
# 0               -0.005             0.003  ...            -0.002
# 1               -0.004             0.008  ...            -0.002
# 2               -0.003             0.010  ...            -0.004
# 3               -0.005             0.009  ...            -0.005
# 4               -0.006             0.023  ...            -0.003
# ...                ...               ...  ...               ...
# 8534            -0.005            -0.001  ...            -0.004
# 8535            -0.002            -0.001  ...            -0.003
# 8536             0.000            -0.004  ...            -0.002
# 8537             0.001            -0.004  ...             0.002
# 8538             0.000            -0.003  ...             0.002
#
#       r0992.moving.Fst  r0993.moving.Fst  r0994.moving.Fst  r0995.moving.Fst  \
# 0               -0.001             0.000            -0.002            -0.005
# 1               -0.005             0.005            -0.001            -0.005
# 2               -0.004             0.008             0.000            -0.006
# 3               -0.003             0.011             0.001            -0.003
# 4               -0.006             0.013             0.002            -0.007
# ...                ...               ...               ...               ...
# 8534            -0.005            -0.005             0.005            -0.004
# 8535            -0.004            -0.004             0.002            -0.004
# 8536            -0.004             0.000            -0.002            -0.005
# 8537            -0.005            -0.002             0.001            -0.004
# 8538            -0.004            -0.001             0.007            -0.004
#
#       r0996.moving.Fst  r0997.moving.Fst  r0998.moving.Fst  r0999.moving.Fst  \
# 0               -0.002            -0.004             0.001            -0.001
# 1               -0.003            -0.005             0.005            -0.003
# 2               -0.002            -0.006             0.009            -0.001
# 3               -0.002            -0.005             0.013             0.002
# 4               -0.002             0.001             0.025            -0.005
# ...                ...               ...               ...               ...
# 8534            -0.003            -0.004            -0.003             0.001
# 8535            -0.003            -0.005             0.001             0.001
# 8536            -0.005            -0.004            -0.003             0.003
# 8537            -0.004            -0.001            -0.002            -0.001
# 8538            -0.003             0.003            -0.002             0.000
#
#       r1000.moving.Fst
# 0                0.002
# 1                0.001
# 2               -0.002
# 3               -0.002
# 4               -0.005
# ...                ...
# 8534            -0.002
# 8535            -0.001
# 8536            -0.003
# 8537            -0.002
# 8538            -0.001
#
# [8539 rows x 1003 columns]

# %%
df_true_fst = df[['window.pos','phenotype.moving.Fst']]

# %%
df_true_fst.sort_values('phenotype.moving.Fst',ascending=False,inplace=True)
# Out:
# C:\Users\santiago.guillen\.conda\envs\MLBasic\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
df_true_fst.to_csv('../../data/repository/Korle-bu_PM.rnk',sep='\t',header=False,index=False)

# %%
# extract non overlaping windows
df_list = list()
start_point = 0
n_pos = df.shape[0]
window_size = 55

mosquito = 'Korle-bu'
insct = 'PM'
file_name = '../../data/repository/'+mosquito+'_'+insct+'_'+str(window_size)+'.gmt'

for i in range(0,n_pos,window_size):
    if i == 0:
        df_tmp = df.loc[i:i + window_size - 1,['window.pos']]
        df_list.append(df_tmp.rename(columns={'window.pos':'window_'+str(i)}).T)
        continue
    if i + window_size > n_pos:
        df_tmp = df.loc[i:n_pos-1,['window.pos']]
        df_tmp = df_tmp.rename(columns={'window.pos':'window_'+str(i)}).T
        last_columns = df_tmp.shape[1]
        df_tmp.columns = df_list[0].columns[0:last_columns]
        #df_list.append(df_tmp)
        break
    df_tmp = df.loc[i:i + window_size - 1,['window.pos']]
    df_tmp = df_tmp.rename(columns={'window.pos':'window_'+str(i)}).T
    df_tmp.columns = df_list[0].columns
    df_list.append(df_tmp)

# %%
df_tmp.index[0]
# Out:
# 'window_8480'

# %%
df_print
# Out:
#                    0         1         2         3         4         5   \
# window_0       334240    527970    765225   1079162   1458737   1715014
# window_80     6733821   6760728   6792726   6823575   6852701   6877742
# window_160    9631663   9661718   9681953   9739593   9776168   9813097
# window_240   11794781  11816293  11841129  11868979  11892930  11914698
# window_320   14058466  14082711  14100062  14120638  14137712  14153877
# ...               ...       ...       ...       ...       ...       ...
# window_8080   3989934   4016238   4036696   4058345   4078983   4108304
# window_8160   6079348   6101396   6122227   6145124   6201894   6226588
# window_8240   8301247   8321545   8341924   8361723   8383288   8406043
# window_8320  10398248  10423964  10445580  10473511  10508125  10543601
# window_8400  12618388  12685325  12735048  12767024  12817351  12859668
#
#                    6         7         8         9   ...        70        71  \
# window_0      2049229   2644556   3023008   3125960  ...   6349656   6402535
# window_80     6902517   6932772   6960756   6989945  ...   9329957   9352106
# window_160    9846706   9877787   9900676   9927113  ...  11516834  11549932
# window_240   11936574  11958557  11980906  12006658  ...  13796856  13821064
# window_320   14170754  14194909  14212724  14231959  ...  15459073  15481212
# ...               ...       ...       ...       ...  ...       ...       ...
# window_8080   4126885   4158285   4183884   4204750  ...   5815359   5842028
# window_8160   6259375   6282203   6305715   6337144  ...   8009640   8043740
# window_8240   8431908   8460239   8478114   8499286  ...  10176427  10196901
# window_8320  10564867  10583002  10605537  10623222  ...  12372958  12394813
# window_8400  12885173  12903654  12935634  12969139  ...  15020951  15229157
#
#                    72        73        74        75        76        77  \
# window_0      6439142   6469243   6506556   6537900   6589138   6627761
# window_80     9383584   9411595   9444035   9470928   9503134   9541286
# window_160   11593097  11619157  11647261  11672501  11697888  11722046
# window_240   13837711  13856626  13881465  13922507  13963437  13986166
# window_320   15499575  15515125  15531404  15551301  15574192  15598841
# ...               ...       ...       ...       ...       ...       ...
# window_8080   5870910   5921264   5945144   5969248   5991840   6015249
# window_8160   8077234   8106023   8144863   8172713   8197795   8224273
# window_8240  10216799  10238751  10262094  10285232  10306852  10332142
# window_8320  12411885  12434136  12457510  12477788  12503495  12530315
# window_8400  15337973  15494347  15578975  15674954  15750712  15807968
#
#                    78        79
# window_0      6662797   6694215
# window_80     9570974   9599616
# window_160   11746211  11775533
# window_240   14009339  14025425
# window_320   15619179  15642963
# ...               ...       ...
# window_8080   6039182   6059365
# window_8160   8248604   8277183
# window_8240  10358956  10377368
# window_8320  12562443  12589523
# window_8400  15875946  15927876
#
# [106 rows x 80 columns]

# %%
mosquito = 'Korle-bu'
insct = 'PM'
file_name = '../../data/repository/'+mosquito+'_'+insct+'_'+str(window_size)+'.gmt'
file_name
df_print.to_csv(file_name,sep='\t',header=False)
